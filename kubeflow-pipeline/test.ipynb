# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/prichoud3/Documents/MLOps-Tutorial/terraform/gcp-creds.json"

# %%
from google.api_core.client_options import ClientOptions
from google.cloud import bigquery
from google.cloud.aiplatform import Featurestore
from google.cloud.bigquery.table import TableReference

params = {
    'PROJECT_ID': "gcp-tutorial-400612",
    'REGION': "us-central1",
    'ONLINE_STORE_FIXED_NODE_COUNT': 1,
    'TEMP_DATASET': "dataset_011023",
    'TEMP_SRC_TABLE': "preprocessed_data",
    'NEW_FEATURE_STORE_NAME': "feature_store_21023"
}
PROJECT_ID=params['PROJECT_ID']
REGION=params['REGION']
ONLINE_STORE_FIXED_NODE_COUNT=params['ONLINE_STORE_FIXED_NODE_COUNT']
TEMP_DATASET=params['TEMP_DATASET']
TEMP_SRC_TABLE=params['TEMP_SRC_TABLE']
NEW_FEATURE_STORE_NAME=params['NEW_FEATURE_STORE_NAME']

BQ_CLIENT_INFO = ClientOptions(quota_project_id = PROJECT_ID)
BQ_CLIENT = bigquery.client.Client(project = PROJECT_ID, 
                                    client_options=BQ_CLIENT_INFO)

def map_dtype_to_featurestore(feature_type):
    if feature_type == "STRING":
        return "STRING"
    elif feature_type in ["INTEGER", "INT", "SMALLINT", "INTEGER", "BIGINT", "TINYINT", "BYTEINT", "INT64"]:
        return "INT64"
    elif feature_type.startswith("ARRAY") or feature_type.startswith("STRUCT"):
        raise "Cannot process source table having columns with datatype " + feature_type
    elif feature_type in ["BIGNUMERIC", "NUMERIC", "DECIMAL", "BIGDECIMAL", "FLOAT64", "FLOAT"]:
        return "DOUBLE"
    elif feature_type.startswith("BIGNUMERIC") or feature_type.startswith("NUMERIC") or feature_type.startswith("DECIMAL") or feature_type.startswith("BIGDECIMAL"):
        return "DOUBLE"
    elif feature_type == "BOOL":
        return "BOOL"
    elif feature_type == "BYTES":
        return "BYTES"
    elif feature_type in ["DATE", "DATETIME", "INTERVAL", "TIME", "TIMESTAMP"]:
        return "STRING"
    elif feature_type == "JSON":
        return "STRING"
    else:
        return "STRING"


def populate_feature_store(name):
    fs_already_exists = False

    # Check if already exists
    try:
        fs = Featurestore(
            featurestore_name=name,
            project=PROJECT_ID,
            location=REGION,
        )
        print('Feature Store already exists')
        preprocessed_entity_type = fs.get_entity_type(
            entity_type_id="preprocessed"
        )
        fs_already_exists = True
        return fs, preprocessed_entity_type, fs_already_exists
    except Exception as e:
        print('Feature Store does not exists. Creating Feature Store')
        fs = Featurestore.create(
            featurestore_id=name,
            online_store_fixed_node_count=ONLINE_STORE_FIXED_NODE_COUNT,
            project=PROJECT_ID,
            location=REGION,
            sync=True,
        )

    fs = Featurestore(
        featurestore_name=name,
        project=PROJECT_ID,
        location=REGION,
    )
    print(f"{fs.gca_resource=}")

    preprocessed_entity_type = fs.create_entity_type(
        entity_type_id="preprocessed",
        description="Reading of metadata from app",
    )
    table_obj = BQ_CLIENT.get_table('{}.{}.{}'.format(PROJECT_ID, TEMP_DATASET, TEMP_SRC_TABLE))
    for s in table_obj.schema:
        preprocessed_entity_type.create_feature(
            feature_id=s.name.lower(),
            value_type=map_dtype_to_featurestore(s.field_type),
            # description="Unnamed integer column",
        )

    return fs, preprocessed_entity_type, fs_already_exists

def get_feature_source_fields(preprocessed_entity_type):
    lof = preprocessed_entity_type.list_features(order_by='create_time')
    lofn = [f.name for f in lof]
    # LOGGER.info(lofn)

    src_table = BQ_CLIENT.get_table(TableReference.from_string('{}.{}.{}'.format(PROJECT_ID, TEMP_DATASET, TEMP_SRC_TABLE), default_project=PROJECT_ID))
    columns = [s.name for s in src_table.schema]

    print('Obtained mapping from feature store to bigquery')
    return lofn, dict(zip(lofn, columns))



def populate_features_extract_features(fs, preprocessed_entity_type, fs_already_exists):
    try:
        lofn, feature_source_fields = get_feature_source_fields(preprocessed_entity_type)
        if fs_already_exists is False:
            preprocessed_entity_type.ingest_from_bq(
                feature_ids=lofn,
                feature_time="created_at",
                bq_source_uri='bq://{}.{}.{}'.format(PROJECT_ID, TEMP_DATASET, TEMP_SRC_TABLE),
                feature_source_fields=feature_source_fields,
                entity_id_field='Address',
                disable_online_serving=False,
                sync=True
            )
            print('Ingested Bigquery Source table into Feature Store')
    except:
        print('Error populating features in bigquery')
        raise

# %%
fs, preprocessed_entity_type, fs_already_exists = populate_feature_store(NEW_FEATURE_STORE_NAME)
# Out:
# Feature Store does not exists. Creating Feature Store
# Creating Featurestore
# Create Featurestore backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/operations/1841782787997171712
# Featurestore created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023
# To use this Featurestore in another session:
# featurestore = aiplatform.Featurestore('projects/836048009338/locations/us-central1/featurestores/feature_store_21023')
# fs.gca_resource=name: "projects/836048009338/locations/us-central1/featurestores/feature_store_21023"
# create_time {
#   seconds: 1696198075
#   nanos: 512194000
# }
# update_time {
#   seconds: 1696198075
#   nanos: 709250000
# }
# etag: "AMEw9yPw6cYYdJiSLou_c8YkyfwQLsX1ZKltpZYFs0Pzql-JroKxDzIft69rHxDmKHe5"
# online_serving_config {
#   fixed_node_count: 1
# }
# state: STABLE
# online_storage_ttl_days: 4000
#
# Creating EntityType
# Create EntityType backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/operations/7640167308236685312
# EntityType created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed
# To use this EntityType in another session:
# entity_type = aiplatform.EntityType('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/date/operations/3539639847515848704
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/date
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/date')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/address/operations/3282934668755730432
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/address
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/address')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/type/operations/4863698137962774528
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/type
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/type')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/method/operations/3418042657576845312
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/method
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/method')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/councilarea/operations/6665137988910972928
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/councilarea
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/councilarea')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/regionname/operations/6368322625969586176
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/regionname
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/regionname')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/rooms/operations/7434127625284485120
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/rooms
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/rooms')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/price/operations/1686408600852889600
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/price
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/price')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/distance/operations/1669520102250250240
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/distance
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/distance')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/postcode/operations/7219502955542609920
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/postcode
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/postcode')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/bedroom2/operations/1186509042214764544
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/bedroom2
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/bedroom2')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/bathroom/operations/5798195060642152448
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/bathroom
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/bathroom')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/car/operations/5110270217561309184
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/car
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/car')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/landsize/operations/7941908483270508544
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/landsize
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/landsize')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/buildingarea/operations/6281206120677638144
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/buildingarea
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/buildingarea')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/yearbuilt/operations/4683976365333020672
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/yearbuilt
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/yearbuilt')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/lattitude/operations/1468406231390486528
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/lattitude
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/lattitude')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/longtitude/operations/7574865113639813120
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/longtitude
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/longtitude')
# Creating Feature
# Create Feature backing LRO: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/propertycount/operations/3779456527673327616
# Feature created. Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/propertycount
# To use this Feature in another session:
# feature = aiplatform.Feature('projects/836048009338/locations/us-central1/featurestores/feature_store_21023/entityTypes/preprocessed/features/propertycount')

# %%
populate_features_extract_features(fs, preprocessed_entity_type, fs_already_exists)
# Out:
# Error populating features in bigquery
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:75, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      74 try:
# ---> 75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/grpc/_channel.py:1161, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1155 (
#    1156     state,
#    1157     call,
#    1158 ) = self._blocking(
#    1159     request, timeout, metadata, credentials, wait_for_ready, compression
#    1160 )
# -> 1161 return _end_unary_response_blocking(state, call, False, None)
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/grpc/_channel.py:1004, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1003 else:
# -> 1004     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.NOT_FOUND
# 	details = "The Featurestore does not exist."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B2404:6800:4009:800::200a%5D:443 {grpc_message:"The Featurestore does not exist.", grpc_status:5, created_time:"2023-10-02T14:17:35.270622+05:30"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# NotFound                                  Traceback (most recent call last)
# /Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> populate_features_extract_features(fs, preprocessed_entity_type, fs_already_exists)
#
# /Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb Cell 4 line 1
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=107'>108</a> def populate_features_extract_features(fs, preprocessed_entity_type, fs_already_exists):
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=108'>109</a>     try:
# --> <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=109'>110</a>         lofn, feature_source_fields = get_feature_source_fields(preprocessed_entity_type)
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=110'>111</a>         if fs_already_exists is False:
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=111'>112</a>             preprocessed_entity_type.ingest_from_bq(
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=112'>113</a>                 feature_ids=lofn,
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=113'>114</a>                 feature_time="Date",
#    (...)
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=118'>119</a>                 sync=True
#     <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=119'>120</a>             )
#
# /Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb Cell 4 line 9
#      <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=94'>95</a> def get_feature_source_fields(preprocessed_entity_type):
# ---> <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=95'>96</a>     lof = preprocessed_entity_type.list_features(order_by='create_time')
#      <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=96'>97</a>     lofn = [f.name for f in lof]
#      <a href='vscode-notebook-cell:/Users/prichoud3/Documents/MLOps-Tutorial/kubeflow-pipeline/test.ipynb#W4sZmlsZQ%3D%3D?line=97'>98</a>     # LOGGER.info(lofn)
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/cloud/aiplatform/featurestore/_entity_type.py:412, in _EntityType.list_features(self, filter, order_by)
#     363 """Lists existing managed feature resources in this EntityType.
#     364
#     365 Example Usage:
#    (...)
#     409     List[featurestore.Feature] - A list of managed feature resource objects.
#     410 """
#     411 self.wait()
# --> 412 return featurestore.Feature.list(
#     413     entity_type_name=self.resource_name,
#     414     filter=filter,
#     415     order_by=order_by,
#     416 )
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/cloud/aiplatform/featurestore/feature.py:330, in Feature.list(cls, entity_type_name, featurestore_id, filter, order_by, project, location, credentials)
#     249 @classmethod
#     250 def list(
#     251     cls,
#    (...)
#     258     credentials: Optional[auth_credentials.Credentials] = None,
#     259 ) -> List["Feature"]:
#     260     """Lists existing managed feature resources in an entityType, given an entityType resource name or an entity_type ID.
#     261
#     262     Example Usage:
#    (...)
#     327         List[Feature] - A list of managed feature resource objects
#     328     """
# --> 330     return cls._list(
#     331         filter=filter,
#     332         order_by=order_by,
#     333         project=project,
#     334         location=location,
#     335         credentials=credentials,
#     336         parent=utils.full_resource_name(
#     337             resource_name=entity_type_name,
#     338             resource_noun=featurestore.EntityType._resource_noun,
#     339             parse_resource_name_method=featurestore.EntityType._parse_resource_name,
#     340             format_resource_name_method=featurestore.EntityType._format_resource_name,
#     341             parent_resource_name_fields={
#     342                 featurestore.Featurestore._resource_noun: featurestore_id
#     343             }
#     344             if featurestore_id
#     345             else featurestore_id,
#     346             project=project,
#     347             location=location,
#     348             resource_id_validator=featurestore.EntityType._resource_id_validator,
#     349         ),
#     350     )
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/cloud/aiplatform/base.py:1128, in VertexAiResourceNounWithFutureManager._list(cls, cls_filter, filter, order_by, read_mask, project, location, credentials, parent)
#    1125 if order_by:
#    1126     list_request["order_by"] = order_by
# -> 1128 resource_list = resource_list_method(request=list_request) or []
#    1130 return [
#    1131     cls._construct_sdk_resource_from_gapic(
#    1132         gapic_resource, project=project, location=location, credentials=creds
#    (...)
#    1135     if cls_filter(gapic_resource)
#    1136 ]
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/cloud/aiplatform_v1/services/featurestore_service/client.py:2320, in FeaturestoreServiceClient.list_features(self, request, parent, retry, timeout, metadata)
#    2315 metadata = tuple(metadata) + (
#    2316     gapic_v1.routing_header.to_grpc_metadata((("parent", request.parent),)),
#    2317 )
#    2319 # Send the request.
# -> 2320 response = rpc(
#    2321     request,
#    2322     retry=retry,
#    2323     timeout=timeout,
#    2324     metadata=metadata,
#    2325 )
#    2327 # This method is paged; wrap the response in a pager, which provides
#    2328 # an `__iter__` convenience method.
#    2329 response = pagers.ListFeaturesPager(
#    2330     method=rpc,
#    2331     request=request,
#    2332     response=response,
#    2333     metadata=metadata,
#    2334 )
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/anaconda3/envs/mlops/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# NotFound: 404 The Featurestore does not exist.

# %%
fs.get_entity_type("preprocessed").read(entity_ids="preprocessed",feature_ids=["rooms"])
# Out:
#       entity_id rooms
# 0  preprocessed  None

# %%
fs.delete("feature_store_21023", force=True)
# Out:
# Deleting Featurestore : projects/836048009338/locations/us-central1/featurestores/feature_store_21023
# Delete Featurestore  backing LRO: projects/836048009338/locations/us-central1/operations/6298094619280277504
# Featurestore deleted. . Resource name: projects/836048009338/locations/us-central1/featurestores/feature_store_21023
